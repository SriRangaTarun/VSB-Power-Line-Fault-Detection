# %% [markdown]
# ### This kernel is forked from [this wonderful kernel](https://www.kaggle.com/braquino/5-fold-lstm-attention-fully-commented-0-694) by Bruno Aquino. I have just added a Capsule layer and stacked the recurrent layers together. Additionally, I have done some feature engineering based on time series entropy and fractal dimension.
#
# Feature Engineering : [Raphael Vallat's entropy repository](https://github.com/raphaelvallat/entropy/blob/master/entropy/utils.py)
# AND
# Capsule Layer : [keras-contrib](https://github.com/keras-team/keras-contrib/blob/master/keras_contrib/layers/capsule.py)

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import *
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
from keras import activations
from keras import regularizers
from keras import initializers
from keras import constraints
from sklearn.preprocessing import MinMaxScaler
from numba import jit
from math import log, floor
from sklearn.neighbors import KDTree
from scipy.signal import periodogram, welch
# import gplearn
# from gplearn.genetic import SymbolicTransformer
# from gplearn.functions import make_function
# Out:
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
def squash(x, axis=-1):
    """
    Squash activation function (generally used in Capsule layers).
    """
    s_squared_norm = K.sum(K.square(x), axis, keepdims=True) + K.epsilon()
    scale = K.sqrt(s_squared_norm) / (0.5 + s_squared_norm)
    return scale * x


class Capsule(Layer):
    """Capsule Layer implementation in Keras
       This implementation is based on Dynamic Routing of Capsules,
       Geoffrey Hinton et. al.
       The Capsule Layer is a Neural Network Layer which helps
       modeling relationships in image and sequential data better
       than just CNNs or RNNs. It achieves this by understanding
       the spatial relationships between objects (in images)
       or words (in text) by encoding additional information
       about the image or text, such as angle of rotation,
       thickness and brightness, relative proportions etc.
       This layer can be used instead of pooling layers to
       lower dimensions and still capture important information
       about the relationships and structures within the data.
       A normal pooling layer would lose a lot of
       this information.
       This layer can be used on the output of any layer
       which has a 3-D output (including batch_size). For example,
       in image classification, it can be used on the output of a
       Conv2D layer for Computer Vision applications. Also,
       it can be used on the output of a GRU or LSTM Layer
       (Bidirectional or Unidirectional) for NLP applications.
       The default activation function is 'linear'. But, this layer
       is generally used with the 'squash' activation function
       (recommended). To use the squash activation function, do :
       from keras_contrib.activations import squash
       capsule = Capsule(num_capsule=10,
                         dim_capsule=10,
                         routings=3,
                         share_weights=True,
                         activation=squash)
       # Example usage :
           1). COMPUTER VISION
           input_image = Input(shape=(None, None, 3))
           conv_2d = Conv2D(64,
                            (3, 3),
                            activation='relu')(input_image)
           capsule = Capsule(num_capsule=10,
                             dim_capsule=16,
                             routings=3,
                             activation='relu',
                             share_weights=True)(conv_2d)
           2). NLP
           maxlen = 72
           max_features = 120000
           input_text = Input(shape=(maxlen,))
           embedding = Embedding(max_features,
                                 embed_size,
                                 weights=[embedding_matrix],
                                 trainable=False)(input_text)
           bi_gru = Bidirectional(GRU(64,
                                      return_seqeunces=True))(embedding)
           capsule = Capsule(num_capsule=5,
                             dim_capsule=5,
                             routings=4,
                             activation='sigmoid',
                             share_weights=True)(bi_gru)
       # Arguments
           num_capsule : Number of Capsules (int)
           dim_capsules : Dimensions of the vector output of each Capsule (int)
           routings : Number of dynamic routings in the Capsule Layer (int)
           share_weights : Whether to share weights between Capsules or not
           (boolean)
           activation : Activation function for the Capsules
           regularizer : Regularizer for the weights of the Capsules
           initializer : Initializer for the weights of the Caspules
           constraint : Constraint for the weights of the Capsules
       # Input shape
            3D tensor with shape:
            (batch_size, input_num_capsule, input_dim_capsule)
            [any 3-D Tensor with the first dimension as batch_size]
       # Output shape
            3D tensor with shape:
            (batch_size, num_capsule, dim_capsule)
       # References
        - [Dynamic-Routing-Between-Capsules]
          (https://arxiv.org/pdf/1710.09829.pdf)
        - [Keras-Examples-CIFAR10-CNN-Capsule]"""

    def __init__(self,
                 num_capsule,
                 dim_capsule,
                 routings=3,
                 share_weights=True,
                 initializer='glorot_uniform',
                 activation=squash,
                 regularizer=None,
                 constraint=None,
                 **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights

        self.activation = activations.get(activation)
        self.regularizer = regularizers.get(regularizer)
        self.initializer = initializers.get(initializer)
        self.constraint = constraints.get(constraint)

    def build(self, input_shape):
        input_dim_capsule = input_shape[-1]
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1,
                                            input_dim_capsule,
                                            self.num_capsule *
                                            self.dim_capsule),
                                     initializer=self.initializer,
                                     regularizer=self.regularizer,
                                     constraint=self.constraint,
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule *
                                            self.dim_capsule),
                                     initializer=self.initializer,
                                     regularizer=self.regularizer,
                                     constraint=self.constraint,
                                     trainable=True)

        self.build = True

    def call(self, inputs):
        if self.share_weights:
            u_hat_vectors = K.conv1d(inputs, self.W)
        else:
            u_hat_vectors = K.local_conv1d(inputs, self.W, [1], [1])

        # u_hat_vectors : The spatially transformed input vectors (with local_conv_1d)

        batch_size = K.shape(inputs)[0]
        input_num_capsule = K.shape(inputs)[1]
        u_hat_vectors = K.reshape(u_hat_vectors, (batch_size,
                                                  input_num_capsule,
                                                  self.num_capsule,
                                                  self.dim_capsule))

        u_hat_vectors = K.permute_dimensions(u_hat_vectors, (0, 2, 1, 3))
        routing_weights = K.zeros_like(u_hat_vectors[:, :, :, 0])

        for i in range(self.routings):
            capsule_weights = K.softmax(routing_weights, 1)
            outputs = K.batch_dot(capsule_weights, u_hat_vectors, [2, 2])
            if K.ndim(outputs) == 4:
                outputs = K.sum(outputs, axis=1)
            if i < self.routings - 1:
                outputs = K.l2_normalize(outputs, -1)
                routing_weights = K.batch_dot(outputs, u_hat_vectors, [2, 3])
                if K.ndim(routing_weights) == 4:
                    routing_weights = K.sum(routing_weights, axis=1)

        return self.activation(outputs)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

    def get_config(self):
        config = {'num_capsule': self.num_capsule,
                  'dim_capsule': self.dim_capsule,
                  'routings': self.routings,
                  'share_weights': self.share_weights,
                  'activation': activations.serialize(self.activation),
                  'regularizer': regularizers.serialize(self.regularizer),
                  'initializer': initializers.serialize(self.initializer),
                  'constraint': constraints.serialize(self.constraint)}

        base_config = super(Capsule, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        # now, we just add all the features to new_ts and convert it to np.array
        new_ts.append(np.concatenate([np.asarray([mean, std, std_top, std_bot, max_range]),percentil_calc, relative_percentile]))
    return np.asarray(new_ts)

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
X = []
y = []
def load_all():
    total_size = len(df_train)
    for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
        X_temp, y_temp = prep_data(ini, end)
        X.append(X_temp)
        y.append(y_temp)
load_all()
X = np.concatenate(X)
y = np.concatenate(y)
# Out:
# 100%|██████████| 1452/1452 [07:25<00:00,  3.19it/s]
# 100%|██████████| 1452/1452 [07:21<00:00,  3.20it/s]

# %%
def petrosian_fd(x):
    """Petrosian fractal dimension.
    Parameters
    ----------
    x : list or np.array
        One dimensional time series
    Returns
    -------
    pfd : float
        Petrosian fractal dimension
    Notes
    -----
    The Petrosian algorithm can be used to provide a fast computation of
    the FD of a signal by translating the series into a binary sequence.
    The Petrosian fractal dimension of a time series :math:`x` is defined by:
    .. math:: \dfrac{log_{10}(N)}{log_{10}(N) +
       log_{10}(\dfrac{N}{N+0.4N_{\Delta}})}
    where :math:`N` is the length of the time series, and
    :math:`N_{\Delta}` is the number of sign changes in the binary sequence.
    Original code from the pyrem package by Quentin Geissmann.
    References
    ----------
    .. [1] A. Petrosian, Kolmogorov complexity of finite sequences and
       recognition of different preictal EEG patterns, in , Proceedings of the
       Eighth IEEE Symposium on Computer-Based Medical Systems, 1995,
       pp. 212-217.
    .. [2] Goh, Cindy, et al. "Comparison of fractal dimension algorithms for
       the computation of EEG biomarkers for dementia." 2nd International
       Conference on Computational Intelligence in Medicine and Healthcare
       (CIMED2005). 2005.
    Examples
    --------
    Petrosian fractal dimension.
        >>> import numpy as np
        >>> from entropy import petrosian_fd
        >>> np.random.seed(123)
        >>> x = np.random.rand(100)
        >>> print(petrosian_fd(x))
            1.0505
    """
    n = len(x)
    # Number of sign changes in the first derivative of the signal
    diff = np.ediff1d(x)
    N_delta = (diff[1:-1] * diff[0:-2] < 0).sum()
    return np.log10(n) / (np.log10(n) + np.log10(n / (n + 0.4 * N_delta)))


def katz_fd(x):
    """Katz Fractal Dimension.
    Parameters
    ----------
    x : list or np.array
        One dimensional time series
    Returns
    -------
    kfd : float
        Katz fractal dimension
    Notes
    -----
    The Katz Fractal dimension is defined by:
    .. math:: FD_{Katz} = \dfrac{log_{10}(n)}{log_{10}(d/L)+log_{10}(n)}
    where :math:`L` is the total length of the time series and :math:`d`
    is the Euclidean distance between the first point in the
    series and the point that provides the furthest distance
    with respect to the first point.
    Original code from the mne-features package by Jean-Baptiste Schiratti
    and Alexandre Gramfort.
    References
    ----------
    .. [1] Esteller, R. et al. (2001). A comparison of waveform fractal
           dimension algorithms. IEEE Transactions on Circuits and Systems I:
           Fundamental Theory and Applications, 48(2), 177-183.
    .. [2] Goh, Cindy, et al. "Comparison of fractal dimension algorithms for
           the computation of EEG biomarkers for dementia." 2nd International
           Conference on Computational Intelligence in Medicine and Healthcare
           (CIMED2005). 2005.
    Examples
    --------
    Katz fractal dimension.
        >>> import numpy as np
        >>> from entropy import katz_fd
        >>> np.random.seed(123)
        >>> x = np.random.rand(100)
        >>> print(katz_fd(x))
            5.1214
    """
    x = np.array(x)
    dists = np.abs(np.ediff1d(x))
    ll = dists.sum()
    ln = np.log10(np.divide(ll, dists.mean()))
    aux_d = x - x[0]
    d = np.max(np.abs(aux_d[1:]))
    return np.divide(ln, np.add(ln, np.log10(np.divide(d, ll))))

@jit('UniTuple(float64, 2)(float64[:], float64[:])', nopython=True)
def _linear_regression(x, y):
    """Fast linear regression using Numba.
    Parameters
    ----------
    x, y : ndarray, shape (n_times,)
        Variables
    Returns
    -------
    slope : float
        Slope of 1D least-square regression.
    intercept : float
        Intercept
    """
    n_times = x.size
    sx2 = 0
    sx = 0
    sy = 0
    sxy = 0
    for j in range(n_times):
        sx2 += x[j] ** 2
        sx += x[j]
        sxy += x[j] * y[j]
        sy += y[j]
    den = n_times * sx2 - (sx ** 2)
    num = n_times * sxy - sx * sy
    slope = num / den
    intercept = np.mean(y) - slope * np.mean(x)
    return slope, intercept


@jit('i8[:](f8, f8, f8)', nopython=True)
def _log_n(min_n, max_n, factor):
    """
    Creates a list of integer values by successively multiplying a minimum
    value min_n by a factor > 1 until a maximum value max_n is reached.
    Used for detrended fluctuation analysis (DFA).
    Function taken from the nolds python package
    (https://github.com/CSchoel/nolds) by Christopher Scholzel.
    Parameters
    ----------
    min_n (float):
        minimum value (must be < max_n)
    max_n (float):
        maximum value (must be > min_n)
    factor (float):
       factor used to increase min_n (must be > 1)
    Returns
    -------
    list of integers:
        min_n, min_n * factor, min_n * factor^2, ... min_n * factor^i < max_n
        without duplicates
    """
    max_i = int(floor(log(1.0 * max_n / min_n) / log(factor)))
    ns = [min_n]
    for i in range(max_i + 1):
        n = int(floor(min_n * (factor ** i)))
        if n > ns[-1]:
            ns.append(n)
    return np.array(ns, dtype=np.int64)

@jit('float64(float64[:], int32)')
def _higuchi_fd(x, kmax):
    """Utility function for `higuchi_fd`.
    """
    n_times = x.size
    lk = np.empty(kmax)
    x_reg = np.empty(kmax)
    y_reg = np.empty(kmax)
    for k in range(1, kmax + 1):
        lm = np.empty((k,))
        for m in range(k):
            ll = 0
            n_max = floor((n_times - m - 1) / k)
            n_max = int(n_max)
            for j in range(1, n_max):
                ll += abs(x[m + j * k] - x[m + (j - 1) * k])
            ll /= k
            ll *= (n_times - 1) / (k * n_max)
            lm[m] = ll
        # Mean of lm
        m_lm = 0
        for m in range(k):
            m_lm += lm[m]
        m_lm /= k
        lk[k - 1] = m_lm
        x_reg[k - 1] = log(1. / k)
        y_reg[k - 1] = log(m_lm)
    higuchi, _ = _linear_regression(x_reg, y_reg)
    return higuchi


def higuchi_fd(x, kmax=10):
    """Higuchi Fractal Dimension.
    Parameters
    ----------
    x : list or np.array
        One dimensional time series
    kmax : int
        Maximum delay/offset (in number of samples).
    Returns
    -------
    hfd : float
        Higuchi Fractal Dimension
    Notes
    -----
    Original code from the mne-features package by Jean-Baptiste Schiratti
    and Alexandre Gramfort.
    The `higuchi_fd` function uses Numba to speed up the computation.
    References
    ----------
    .. [1] Higuchi, Tomoyuki. "Approach to an irregular time series on the
       basis of the fractal theory." Physica D: Nonlinear Phenomena 31.2
       (1988): 277-283.
    Examples
    --------
    Higuchi Fractal Dimension
        >>> import numpy as np
        >>> from entropy import higuchi_fd
        >>> np.random.seed(123)
        >>> x = np.random.rand(100)
        >>> print(higuchi_fd(x))
            2.051179
    """
    x = np.asarray(x, dtype=np.float64)
    kmax = int(kmax)
    return _higuchi_fd(x, kmax)

# %%
def _embed(x, order=3, delay=1):
    """Time-delay embedding.
    Parameters
    ----------
    x : 1d-array, shape (n_times)
        Time series
    order : int
        Embedding dimension (order)
    delay : int
        Delay.
    Returns
    -------
    embedded : ndarray, shape (n_times - (order - 1) * delay, order)
        Embedded time-series.
    """
    N = len(x)
    if order * delay > N:
        raise ValueError("Error: order * delay should be lower than x.size")
    if delay < 1:
        raise ValueError("Delay has to be at least 1.")
    if order < 2:
        raise ValueError("Order has to be at least 2.")
    Y = np.zeros((order, N - (order - 1) * delay))
    for i in range(order):
        Y[i] = x[i * delay:i * delay + Y.shape[1]]
    return Y.T

all = ['perm_entropy', 'spectral_entropy', 'svd_entropy', 'app_entropy',
       'sample_entropy']


def perm_entropy(x, order=3, delay=1, normalize=False):
    """Permutation Entropy.
    Parameters
    ----------
    x : list or np.array
        One-dimensional time series of shape (n_times)
    order : int
        Order of permutation entropy
    delay : int
        Time delay
    normalize : bool
        If True, divide by log2(order!) to normalize the entropy between 0
        and 1. Otherwise, return the permutation entropy in bit.
    Returns
    -------
    pe : float
        Permutation Entropy
    Notes
    -----
    The permutation entropy is a complexity measure for time-series first
    introduced by Bandt and Pompe in 2002 [1]_.
    The permutation entropy of a signal :math:`x` is defined as:
    .. math:: H = -\sum p(\pi)log_2(\pi)
    where the sum runs over all :math:`n!` permutations :math:`\pi` of order
    :math:`n`. This is the information contained in comparing :math:`n`
    consecutive values of the time series. It is clear that
    :math:`0 ≤ H (n) ≤ log_2(n!)` where the lower bound is attained for an
    increasing or decreasing sequence of values, and the upper bound for a
    completely random system where all :math:`n!` possible permutations appear
    with the same probability.
    The embedded matrix :math:`Y` is created by:
    .. math:: y(i)=[x_i,x_{i+delay}, ...,x_{i+(order-1) * delay}]
    .. math:: Y=[y(1),y(2),...,y(N-(order-1))*delay)]^T
    References
    ----------
    .. [1] Bandt, Christoph, and Bernd Pompe. "Permutation entropy: a
           natural complexity measure for time series." Physical review letters
           88.17 (2002): 174102.
    Examples
    --------
    1. Permutation entropy with order 2
        >>> from entropy import perm_entropy
        >>> x = [4, 7, 9, 10, 6, 11, 3]
        >>> # Return a value in bit between 0 and log2(factorial(order))
        >>> print(perm_entropy(x, order=2))
            0.918
    2. Normalized permutation entropy with order 3
        >>> from entropy import perm_entropy
        >>> x = [4, 7, 9, 10, 6, 11, 3]
        >>> # Return a value comprised between 0 and 1.
        >>> print(perm_entropy(x, order=3, normalize=True))
            0.589
    """
    x = np.array(x)
    ran_order = range(order)
    hashmult = np.power(order, ran_order)
    # Embed x and sort the order of permutations
    sorted_idx = _embed(x, order=order, delay=delay).argsort(kind='quicksort')
    # Associate unique integer to each permutations
    hashval = (np.multiply(sorted_idx, hashmult)).sum(1)
    # Return the counts
    _, c = np.unique(hashval, return_counts=True)
    # Use np.true_divide for Python 2 compatibility
    p = np.true_divide(c, c.sum())
    pe = -np.multiply(p, np.log2(p)).sum()
    if normalize:
        pe /= np.log2(factorial(order))
    return pe


def spectral_entropy(x, sf, method='fft', nperseg=None, normalize=False):
    """Spectral Entropy.
    Parameters
    ----------
    x : list or np.array
        One-dimensional time series of shape (n_times)
    sf : float
        Sampling frequency
    method : str
        Spectral estimation method ::
        'fft' : Fourier Transform (via scipy.signal.periodogram)
        'welch' : Welch periodogram (via scipy.signal.welch)
    nperseg : str or int
        Length of each FFT segment for Welch method.
        If None, uses scipy default of 256 samples.
    normalize : bool
        If True, divide by log2(psd.size) to normalize the spectral entropy
        between 0 and 1. Otherwise, return the spectral entropy in bit.
    Returns
    -------
    se : float
        Spectral Entropy
    Notes
    -----
    Spectral Entropy is defined to be the Shannon Entropy of the Power
    Spectral Density (PSD) of the data:
    .. math:: H(x, sf) =  -\sum_{f=0}^{f_s/2} PSD(f) log_2[PSD(f)]
    Where :math:`PSD` is the normalised PSD, and :math:`f_s` is the sampling
    frequency.
    References
    ----------
    .. [1] Inouye, T. et al. (1991). Quantification of EEG irregularity by
       use of the entropy of the power spectrum. Electroencephalography
       and clinical neurophysiology, 79(3), 204-210.
    Examples
    --------
    1. Spectral entropy of a pure sine using FFT
        >>> from entropy import spectral_entropy
        >>> import numpy as np
        >>> sf, f, dur = 100, 1, 4
        >>> N = sf * duration # Total number of discrete samples
        >>> t = np.arange(N) / sf # Time vector
        >>> x = np.sin(2 * np.pi * f * t)
        >>> print(np.round(spectral_entropy(x, sf, method='fft'), 2)
            0.0
    2. Spectral entropy of a random signal using Welch's method
        >>> from entropy import spectral_entropy
        >>> import numpy as np
        >>> np.random.seed(42)
        >>> x = np.random.rand(3000)
        >>> print(spectral_entropy(x, sf=100, method='welch'))
            9.939
    3. Normalized spectral entropy
        >>> print(spectral_entropy(x, sf=100, method='welch', normalize=True))
            0.995
    """
    x = np.array(x)
    # Compute and normalize power spectrum
    if method == 'fft':
        _, psd = periodogram(x, sf)
    elif method == 'welch':
        _, psd = welch(x, sf, nperseg=nperseg)
    psd_norm = np.divide(psd, psd.sum())
    se = -np.multiply(psd_norm, np.log2(psd_norm)).sum()
    if normalize:
        se /= np.log2(psd_norm.size)
    return se


def svd_entropy(x, order=3, delay=1, normalize=False):
    """Singular Value Decomposition entropy.
    Parameters
    ----------
    x : list or np.array
        One-dimensional time series of shape (n_times)
    order : int
        Order of permutation entropy
    delay : int
        Time delay
    normalize : bool
        If True, divide by log2(order!) to normalize the entropy between 0
        and 1. Otherwise, return the permutation entropy in bit.
    Returns
    -------
    svd_e : float
        SVD Entropy
    Notes
    -----
    SVD entropy is an indicator of the number of eigenvectors that are needed
    for an adequate explanation of the data set. In other words, it measures
    the dimensionality of the data.
    The SVD entropy of a signal :math:`x` is defined as:
    .. math::
        H = -\sum_{i=1}^{M} \overline{\sigma}_i log_2(\overline{\sigma}_i)
    where :math:`M` is the number of singular values of the embedded matrix
    :math:`Y` and :math:`\sigma_1, \sigma_2, ..., \sigma_M` are the
    normalized singular values of :math:`Y`.
    The embedded matrix :math:`Y` is created by:
    .. math:: y(i)=[x_i,x_{i+delay}, ...,x_{i+(order-1) * delay}]
    .. math:: Y=[y(1),y(2),...,y(N-(order-1))*delay)]^T
    Examples
    --------
    1. SVD entropy with order 2
        >>> from entropy import svd_entropy
        >>> x = [4, 7, 9, 10, 6, 11, 3]
        >>> # Return a value in bit between 0 and log2(factorial(order))
        >>> print(svd_entropy(x, order=2))
            0.762
    2. Normalized SVD entropy with order 3
        >>> from entropy import svd_entropy
        >>> x = [4, 7, 9, 10, 6, 11, 3]
        >>> # Return a value comprised between 0 and 1.
        >>> print(svd_entropy(x, order=3, normalize=True))
            0.687
    """
    x = np.array(x)
    mat = _embed(x, order=order, delay=delay)
    W = np.linalg.svd(mat, compute_uv=False)
    # Normalize the singular values
    W /= sum(W)
    svd_e = -np.multiply(W, np.log2(W)).sum()
    if normalize:
        svd_e /= np.log2(order)
    return svd_e


def _app_samp_entropy(x, order, metric='chebyshev', approximate=True):
    """Utility function for `app_entropy`` and `sample_entropy`.
    """
    _all_metrics = KDTree.valid_metrics
    if metric not in _all_metrics:
        raise ValueError('The given metric (%s) is not valid. The valid '
                         'metric names are: %s' % (metric, _all_metrics))
    phi = np.zeros(2)
    r = 0.2 * np.std(x, axis=-1, ddof=1)

    # compute phi(order, r)
    _emb_data1 = _embed(x, order, 1)
    if approximate:
        emb_data1 = _emb_data1
    else:
        emb_data1 = _emb_data1[:-1]
    count1 = KDTree(emb_data1, metric=metric).query_radius(emb_data1, r,
                                                           count_only=True
                                                           ).astype(np.float64)
    # compute phi(order + 1, r)
    emb_data2 = _embed(x, order + 1, 1)
    count2 = KDTree(emb_data2, metric=metric).query_radius(emb_data2, r,
                                                           count_only=True
                                                           ).astype(np.float64)
    if approximate:
        phi[0] = np.mean(np.log(count1 / emb_data1.shape[0]))
        phi[1] = np.mean(np.log(count2 / emb_data2.shape[0]))
    else:
        phi[0] = np.mean((count1 - 1) / (emb_data1.shape[0] - 1))
        phi[1] = np.mean((count2 - 1) / (emb_data2.shape[0] - 1))
    return phi


@jit('f8(f8[:], i4, f8)', nopython=True)
def _numba_sampen(x, mm=2, r=0.2):
    """
    Fast evaluation of the sample entropy using Numba.
    """
    n = x.size
    n1 = n - 1
    mm += 1
    mm_dbld = 2 * mm

    # Define threshold
    r *= x.std()

    # initialize the lists
    run = [0] * n
    run1 = run[:]
    r1 = [0] * (n * mm_dbld)
    a = [0] * mm
    b = a[:]
    p = a[:]

    for i in range(n1):
        nj = n1 - i

        for jj in range(nj):
            j = jj + i + 1
            if abs(x[j] - x[i]) < r:
                run[jj] = run1[jj] + 1
                m1 = mm if mm < run[jj] else run[jj]
                for m in range(m1):
                    a[m] += 1
                    if j < n1:
                        b[m] += 1
            else:
                run[jj] = 0
        for j in range(mm_dbld):
            run1[j] = run[j]
            r1[i + n * j] = run[j]
        if nj > mm_dbld - 1:
            for j in range(mm_dbld, nj):
                run1[j] = run[j]

    m = mm - 1

    while m > 0:
        b[m] = b[m - 1]
        m -= 1

    b[0] = n * n1 / 2
    a = np.array([float(aa) for aa in a])
    b = np.array([float(bb) for bb in b])
    p = np.true_divide(a, b)
    return -log(p[-1])


def app_entropy(x, order=2, metric='chebyshev'):
    """Approximate Entropy.
    Parameters
    ----------
    x : list or np.array
        One-dimensional time series of shape (n_times)
    order : int (default: 2)
        Embedding dimension.
    metric : str (default: chebyshev)
        Name of the metric function used with
        :class:`~sklearn.neighbors.KDTree`. The list of available
        metric functions is given by: ``KDTree.valid_metrics``.
    Returns
    -------
    ae : float
        Approximate Entropy.
    Notes
    -----
    Original code from the mne-features package.
    Approximate entropy is a technique used to quantify the amount of
    regularity and the unpredictability of fluctuations over time-series data.
    Smaller values indicates that the data is more regular and predictable.
    The value of :math:`r` is set to :math:`0.2 * std(x)`.
    Code adapted from the mne-features package by Jean-Baptiste Schiratti
    and Alexandre Gramfort.
    References
    ----------
    .. [1] Richman, J. S. et al. (2000). Physiological time-series analysis
           using approximate entropy and sample entropy. American Journal of
           Physiology-Heart and Circulatory Physiology, 278(6), H2039-H2049.
    1. Approximate entropy with order 2.
        >>> from entropy import app_entropy
        >>> import numpy as np
        >>> np.random.seed(1234567)
        >>> x = np.random.rand(3000)
        >>> print(app_entropy(x, order=2))
            2.075
    """
    phi = _app_samp_entropy(x, order=order, metric=metric, approximate=True)
    return np.subtract(phi[0], phi[1])


def sample_entropy(x, order=2, metric='chebyshev'):
    """Sample Entropy.
    Parameters
    ----------
    x : list or np.array
        One-dimensional time series of shape (n_times)
    order : int (default: 2)
        Embedding dimension.
    metric : str (default: chebyshev)
        Name of the metric function used with KDTree. The list of available
        metric functions is given by: `KDTree.valid_metrics`.
    Returns
    -------
    se : float
        Sample Entropy.
    Notes
    -----
    Sample entropy is a modification of approximate entropy, used for assessing
    the complexity of physiological time-series signals. It has two advantages
    over approximate entropy: data length independence and a relatively
    trouble-free implementation. Large values indicate high complexity whereas
    smaller values characterize more self-similar and regular signals.
    Sample entropy of a signal :math:`x` is defined as:
    .. math:: H(x, m, r) = -log\dfrac{C(m + 1, r)}{C(m, r)}
    where :math:`m` is the embedding dimension (= order), :math:`r` is
    the radius of the neighbourhood (default = :math:`0.2 * std(x)`),
    :math:`C(m + 1, r)` is the number of embedded vectors of length
    :math:`m + 1` having a Chebyshev distance inferior to :math:`r` and
    :math:`C(m, r)` is the number of embedded vectors of length
    :math:`m` having a Chebyshev distance inferior to :math:`r`.
    Note that if metric == 'chebyshev' and x.size < 5000 points, then the
    sample entropy is computed using a fast custom Numba script. For other
    metric types or longer time-series, the sample entropy is computed using
    a code from the mne-features package by Jean-Baptiste Schiratti
    and Alexandre Gramfort (requires sklearn).
    References
    ----------
    .. [1] Richman, J. S. et al. (2000). Physiological time-series analysis
           using approximate entropy and sample entropy. American Journal of
           Physiology-Heart and Circulatory Physiology, 278(6), H2039-H2049.
    Examples
    --------
    1. Sample entropy with order 2.
        >>> from entropy import sample_entropy
        >>> import numpy as np
        >>> np.random.seed(1234567)
        >>> x = np.random.rand(3000)
        >>> print(sample_entropy(x, order=2))
            2.192
    2. Sample entropy with order 3 using the Euclidean distance.
        >>> from entropy import sample_entropy
        >>> import numpy as np
        >>> np.random.seed(1234567)
        >>> x = np.random.rand(3000)
        >>> print(sample_entropy(x, order=3, metric='euclidean'))
            2.725
    """
    x = np.asarray(x, dtype=np.float64)
    if metric == 'chebyshev' and x.size < 5000:
        return _numba_sampen(x, mm=order, r=0.2)
    else:
        phi = _app_samp_entropy(x, order=order, metric=metric,
                                approximate=False)
        return -np.log(np.divide(phi[1], phi[0]))

# %%
def entropy_and_fractal_dim(x):
    return [perm_entropy(x), svd_entropy(x), app_entropy(x), sample_entropy(x), petrosian_fd(x), katz_fd(x), higuchi_fd(x)]

# %%
signals = X.reshape((len(X), X.shape[1]*X.shape[2]))
features = []

for signal in signals:
    features.append(entropy_and_fractal_dim(signal))

# %%
features = np.array(features).reshape((len(features), 7))
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(features)
features = scaler.transform(features)

# %%
# model = Sequential([Dense(1, activation='sigmoid', input_shape=(7,))])
# model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
# model.fit(x, np.array(list(np.zeros((len(features_zero)))) + list(np.ones((len(features_one))))), epochs=1000)

# %%
# Weights and bias for logistic regression of entropy features
# weights = model.get_weights()[0]
# biases = model.get_weights()[1]

# %%
# print(weights)
# print(biases)

# %%
# e = 2.718281

# exp = make_function(function=lambda x: e**x, name='exp', arity=1)
# tanh = make_function(function=lambda x: (e**(2*x) - 1)/(e**(2*x) + 1), name='tanh', arity=1)

# %%
# function_set = ['add', 'sub', 'mul', 'div',
                # 'sqrt', 'log', 'abs', 'neg', 'inv',
                # 'max', 'min', exp, tanh]

# gp = SymbolicTransformer(generations=10, population_size=2000,
                         # hall_of_fame=100, n_components=50,
                         # function_set=function_set,
                         # parsimony_coefficient=0.0005,
                         # max_samples=0.9, verbose=1,
                         # random_state=0, n_jobs=3)

# gp.fit(features, np.array(list(np.zeros((len(features_zero)))) + list(np.ones((len(features_one))))))

# %%
# engineered_features = gp._programs

# for i in range(len(engineered_features)):
    # for engineered_feature in engineered_features[i]:
        # if engineered_feature != None:
            # print(engineered_feature)

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# save data into file, a numpy specific format
np.save("X.npy",X)
np.save("y.npy",y)
# Out:
# (2904, 160, 57) (2904,)

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape, feat_shape):
    inp = Input(shape=(input_shape[1], input_shape[2],))
    feat = Input(shape=(feat_shape[1],))

    bi_lstm_1 = Bidirectional(CuDNNLSTM(128, return_sequences=True), merge_mode='concat')(inp)
    bi_lstm_2 = Bidirectional(CuDNNGRU(64, return_sequences=True), merge_mode='concat')(bi_lstm_1)
    
    attention = Attention(input_shape[1])(bi_lstm_2)
    # capsule = Capsule(num_capsule=10, dim_capsule=10, routings=4)(bi_gru)
    # capsule = Flatten()(capsule)
    
    # avg_pool = GlobalAveragePooling1D()(bi_gru)
    # max_pool = GlobalMaxPooling1D()(bi_gru)
    
    x = concatenate([attention, feat], axis=1) # capsule, attention_lstm, attention_gru, max_pool, avg_pool
    x = Dense(64, activation="relu")(x)
    x = Dense(1, activation="sigmoid")(x)
    
    model = Model(inputs=[inp, feat], outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_feat, train_y, val_X, val_feat, val_y = X[train_idx], features[train_idx], y[train_idx], X[val_idx], features[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape, features.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit([train_X, train_feat], train_y, batch_size=128, epochs=50, validation_data=([val_X, val_feat], val_y), callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict([val_X, val_feat], batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 6s 3ms/step - loss: 0.3915 - matthews_correlation: 0.0000e+00 - val_loss: 0.2405 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.2313 - matthews_correlation: 0.0000e+00 - val_loss: 0.2221 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.2140 - matthews_correlation: 0.0234 - val_loss: 0.2130 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.2052 - matthews_correlation: 0.0478 - val_loss: 0.1959 - val_matthews_correlation: 0.1923
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.19231, saving model to weights_0.h5
# Epoch 5/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1887 - matthews_correlation: 0.2630 - val_loss: 0.1811 - val_matthews_correlation: 0.2297
#
# Epoch 00005: val_matthews_correlation improved from 0.19231 to 0.22975, saving model to weights_0.h5
# Epoch 6/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1651 - matthews_correlation: 0.3607 - val_loss: 0.2247 - val_matthews_correlation: 0.4917
#
# Epoch 00006: val_matthews_correlation improved from 0.22975 to 0.49173, saving model to weights_0.h5
# Epoch 7/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1635 - matthews_correlation: 0.2272 - val_loss: 0.1441 - val_matthews_correlation: 0.5781
#
# Epoch 00007: val_matthews_correlation improved from 0.49173 to 0.57808, saving model to weights_0.h5
# Epoch 8/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1227 - matthews_correlation: 0.5305 - val_loss: 0.1211 - val_matthews_correlation: 0.3981
#
# Epoch 00008: val_matthews_correlation did not improve from 0.57808
# Epoch 9/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1174 - matthews_correlation: 0.5523 - val_loss: 0.0825 - val_matthews_correlation: 0.6695
#
# Epoch 00009: val_matthews_correlation improved from 0.57808 to 0.66952, saving model to weights_0.h5
# Epoch 10/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1211 - matthews_correlation: 0.5957 - val_loss: 0.0928 - val_matthews_correlation: 0.6162
#
# Epoch 00010: val_matthews_correlation did not improve from 0.66952
# Epoch 11/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1198 - matthews_correlation: 0.5621 - val_loss: 0.0843 - val_matthews_correlation: 0.7654
#
# Epoch 00011: val_matthews_correlation improved from 0.66952 to 0.76543, saving model to weights_0.h5
# Epoch 12/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1079 - matthews_correlation: 0.6012 - val_loss: 0.0843 - val_matthews_correlation: 0.7327
#
# Epoch 00012: val_matthews_correlation did not improve from 0.76543
# Epoch 13/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1071 - matthews_correlation: 0.6117 - val_loss: 0.0866 - val_matthews_correlation: 0.6404
#
# Epoch 00013: val_matthews_correlation did not improve from 0.76543
# Epoch 14/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1076 - matthews_correlation: 0.6516 - val_loss: 0.0819 - val_matthews_correlation: 0.7215
#
# Epoch 00014: val_matthews_correlation did not improve from 0.76543
# Epoch 15/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1119 - matthews_correlation: 0.5591 - val_loss: 0.0829 - val_matthews_correlation: 0.7438
#
# Epoch 00015: val_matthews_correlation did not improve from 0.76543
# Epoch 16/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1095 - matthews_correlation: 0.6338 - val_loss: 0.0824 - val_matthews_correlation: 0.7105
#
# Epoch 00016: val_matthews_correlation did not improve from 0.76543
# Epoch 17/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1046 - matthews_correlation: 0.5335 - val_loss: 0.0734 - val_matthews_correlation: 0.7729
#
# Epoch 00017: val_matthews_correlation improved from 0.76543 to 0.77291, saving model to weights_0.h5
# Epoch 18/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1079 - matthews_correlation: 0.6131 - val_loss: 0.0820 - val_matthews_correlation: 0.7014
#
# Epoch 00018: val_matthews_correlation did not improve from 0.77291
# Epoch 19/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0990 - matthews_correlation: 0.6378 - val_loss: 0.0760 - val_matthews_correlation: 0.7727
#
# Epoch 00019: val_matthews_correlation did not improve from 0.77291
# Epoch 20/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1019 - matthews_correlation: 0.6256 - val_loss: 0.0860 - val_matthews_correlation: 0.7957
#
# Epoch 00020: val_matthews_correlation improved from 0.77291 to 0.79570, saving model to weights_0.h5
# Epoch 21/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1036 - matthews_correlation: 0.6250 - val_loss: 0.0819 - val_matthews_correlation: 0.7840
#
# Epoch 00021: val_matthews_correlation did not improve from 0.79570
# Epoch 22/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1099 - matthews_correlation: 0.6607 - val_loss: 0.0778 - val_matthews_correlation: 0.7928
#
# Epoch 00022: val_matthews_correlation did not improve from 0.79570
# Epoch 23/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0989 - matthews_correlation: 0.6729 - val_loss: 0.0790 - val_matthews_correlation: 0.6904
#
# Epoch 00023: val_matthews_correlation did not improve from 0.79570
# Epoch 24/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1097 - matthews_correlation: 0.5151 - val_loss: 0.0841 - val_matthews_correlation: 0.7391
#
# Epoch 00024: val_matthews_correlation did not improve from 0.79570
# Epoch 25/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1083 - matthews_correlation: 0.6777 - val_loss: 0.0884 - val_matthews_correlation: 0.7447
#
# Epoch 00025: val_matthews_correlation did not improve from 0.79570
# Epoch 26/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1020 - matthews_correlation: 0.6660 - val_loss: 0.0729 - val_matthews_correlation: 0.7822
#
# Epoch 00026: val_matthews_correlation did not improve from 0.79570
# Epoch 27/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0970 - matthews_correlation: 0.6318 - val_loss: 0.0746 - val_matthews_correlation: 0.7442
#
# Epoch 00027: val_matthews_correlation did not improve from 0.79570
# Epoch 28/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0964 - matthews_correlation: 0.6263 - val_loss: 0.0709 - val_matthews_correlation: 0.7600
#
# Epoch 00028: val_matthews_correlation did not improve from 0.79570
# Epoch 29/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0979 - matthews_correlation: 0.6571 - val_loss: 0.0764 - val_matthews_correlation: 0.6852
#
# Epoch 00029: val_matthews_correlation did not improve from 0.79570
# Epoch 30/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0996 - matthews_correlation: 0.6719 - val_loss: 0.0854 - val_matthews_correlation: 0.7150
#
# Epoch 00030: val_matthews_correlation did not improve from 0.79570
# Epoch 31/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0999 - matthews_correlation: 0.6131 - val_loss: 0.0730 - val_matthews_correlation: 0.7984
#
# Epoch 00031: val_matthews_correlation improved from 0.79570 to 0.79837, saving model to weights_0.h5
# Epoch 32/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0954 - matthews_correlation: 0.6455 - val_loss: 0.0750 - val_matthews_correlation: 0.7279
#
# Epoch 00032: val_matthews_correlation did not improve from 0.79837
# Epoch 33/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0994 - matthews_correlation: 0.6456 - val_loss: 0.0753 - val_matthews_correlation: 0.7892
#
# Epoch 00033: val_matthews_correlation did not improve from 0.79837
# Epoch 34/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1003 - matthews_correlation: 0.6402 - val_loss: 0.0926 - val_matthews_correlation: 0.7708
#
# Epoch 00034: val_matthews_correlation did not improve from 0.79837
# Epoch 35/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1029 - matthews_correlation: 0.6636 - val_loss: 0.0892 - val_matthews_correlation: 0.7971
#
# Epoch 00035: val_matthews_correlation did not improve from 0.79837
# Epoch 36/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0947 - matthews_correlation: 0.6591 - val_loss: 0.0757 - val_matthews_correlation: 0.7672
#
# Epoch 00036: val_matthews_correlation did not improve from 0.79837
# Epoch 37/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0924 - matthews_correlation: 0.6561 - val_loss: 0.0732 - val_matthews_correlation: 0.7399
#
# Epoch 00037: val_matthews_correlation did not improve from 0.79837
# Epoch 38/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0933 - matthews_correlation: 0.6449 - val_loss: 0.0707 - val_matthews_correlation: 0.7996
#
# Epoch 00038: val_matthews_correlation improved from 0.79837 to 0.79955, saving model to weights_0.h5
# Epoch 39/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0927 - matthews_correlation: 0.6609 - val_loss: 0.0768 - val_matthews_correlation: 0.7862
#
# Epoch 00039: val_matthews_correlation did not improve from 0.79955
# Epoch 40/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1051 - matthews_correlation: 0.6086 - val_loss: 0.0816 - val_matthews_correlation: 0.6955
#
# Epoch 00040: val_matthews_correlation did not improve from 0.79955
# Epoch 41/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0967 - matthews_correlation: 0.6803 - val_loss: 0.0715 - val_matthews_correlation: 0.7619
#
# Epoch 00041: val_matthews_correlation did not improve from 0.79955
# Epoch 42/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0912 - matthews_correlation: 0.7022 - val_loss: 0.0687 - val_matthews_correlation: 0.8356
#
# Epoch 00042: val_matthews_correlation improved from 0.79955 to 0.83556, saving model to weights_0.h5
# Epoch 43/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0906 - matthews_correlation: 0.6836 - val_loss: 0.0752 - val_matthews_correlation: 0.7750
#
# Epoch 00043: val_matthews_correlation did not improve from 0.83556
# Epoch 44/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0876 - matthews_correlation: 0.7026 - val_loss: 0.0954 - val_matthews_correlation: 0.7839
#
# Epoch 00044: val_matthews_correlation did not improve from 0.83556
# Epoch 45/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1142 - matthews_correlation: 0.6483 - val_loss: 0.0902 - val_matthews_correlation: 0.8258
#
# Epoch 00045: val_matthews_correlation did not improve from 0.83556
# Epoch 46/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0951 - matthews_correlation: 0.6456 - val_loss: 0.0944 - val_matthews_correlation: 0.7822
#
# Epoch 00046: val_matthews_correlation did not improve from 0.83556
# Epoch 47/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0950 - matthews_correlation: 0.6667 - val_loss: 0.0741 - val_matthews_correlation: 0.8303
#
# Epoch 00047: val_matthews_correlation did not improve from 0.83556
# Epoch 48/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0861 - matthews_correlation: 0.6747 - val_loss: 0.0845 - val_matthews_correlation: 0.8194
#
# Epoch 00048: val_matthews_correlation did not improve from 0.83556
# Epoch 49/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0886 - matthews_correlation: 0.6901 - val_loss: 0.0781 - val_matthews_correlation: 0.7988
#
# Epoch 00049: val_matthews_correlation did not improve from 0.83556
# Epoch 50/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0877 - matthews_correlation: 0.6887 - val_loss: 0.0917 - val_matthews_correlation: 0.8044
#
# Epoch 00050: val_matthews_correlation did not improve from 0.83556
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 4s 2ms/step - loss: 0.3756 - matthews_correlation: 9.4756e-04 - val_loss: 0.2494 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2275 - matthews_correlation: 0.0097 - val_loss: 0.2317 - val_matthews_correlation: 0.0530
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.05301, saving model to weights_1.h5
# Epoch 3/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1919 - matthews_correlation: 0.3030 - val_loss: 0.1877 - val_matthews_correlation: 0.2532
#
# Epoch 00003: val_matthews_correlation improved from 0.05301 to 0.25319, saving model to weights_1.h5
# Epoch 4/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1685 - matthews_correlation: 0.3605 - val_loss: 0.1702 - val_matthews_correlation: 0.1045
#
# Epoch 00004: val_matthews_correlation did not improve from 0.25319
# Epoch 5/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1584 - matthews_correlation: 0.3931 - val_loss: 0.1430 - val_matthews_correlation: 0.6130
#
# Epoch 00005: val_matthews_correlation improved from 0.25319 to 0.61302, saving model to weights_1.h5
# Epoch 6/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1346 - matthews_correlation: 0.5160 - val_loss: 0.1118 - val_matthews_correlation: 0.5657
#
# Epoch 00006: val_matthews_correlation did not improve from 0.61302
# Epoch 7/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1219 - matthews_correlation: 0.5883 - val_loss: 0.0977 - val_matthews_correlation: 0.7579
#
# Epoch 00007: val_matthews_correlation improved from 0.61302 to 0.75789, saving model to weights_1.h5
# Epoch 8/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1054 - matthews_correlation: 0.6200 - val_loss: 0.1081 - val_matthews_correlation: 0.6582
#
# Epoch 00008: val_matthews_correlation did not improve from 0.75789
# Epoch 9/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1136 - matthews_correlation: 0.6380 - val_loss: 0.1088 - val_matthews_correlation: 0.7179
#
# Epoch 00009: val_matthews_correlation did not improve from 0.75789
# Epoch 10/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1109 - matthews_correlation: 0.6391 - val_loss: 0.0955 - val_matthews_correlation: 0.6856
#
# Epoch 00010: val_matthews_correlation did not improve from 0.75789
# Epoch 11/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1109 - matthews_correlation: 0.6299 - val_loss: 0.0945 - val_matthews_correlation: 0.7070
#
# Epoch 00011: val_matthews_correlation did not improve from 0.75789
# Epoch 12/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1071 - matthews_correlation: 0.6293 - val_loss: 0.0950 - val_matthews_correlation: 0.7184
#
# Epoch 00012: val_matthews_correlation did not improve from 0.75789
# Epoch 13/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1019 - matthews_correlation: 0.6818 - val_loss: 0.1230 - val_matthews_correlation: 0.6294
#
# Epoch 00013: val_matthews_correlation did not improve from 0.75789
# Epoch 14/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1127 - matthews_correlation: 0.6248 - val_loss: 0.0982 - val_matthews_correlation: 0.7144
#
# Epoch 00014: val_matthews_correlation did not improve from 0.75789
# Epoch 15/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1052 - matthews_correlation: 0.6617 - val_loss: 0.1471 - val_matthews_correlation: 0.5977
#
# Epoch 00015: val_matthews_correlation did not improve from 0.75789
# Epoch 16/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1109 - matthews_correlation: 0.6245 - val_loss: 0.1216 - val_matthews_correlation: 0.6488
#
# Epoch 00016: val_matthews_correlation did not improve from 0.75789
# Epoch 17/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1082 - matthews_correlation: 0.6605 - val_loss: 0.0972 - val_matthews_correlation: 0.6733
#
# Epoch 00017: val_matthews_correlation did not improve from 0.75789
# Epoch 18/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1058 - matthews_correlation: 0.6351 - val_loss: 0.0952 - val_matthews_correlation: 0.6724
#
# Epoch 00018: val_matthews_correlation did not improve from 0.75789
# Epoch 19/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1030 - matthews_correlation: 0.6706 - val_loss: 0.1042 - val_matthews_correlation: 0.6924
#
# Epoch 00019: val_matthews_correlation did not improve from 0.75789
# Epoch 20/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1069 - matthews_correlation: 0.6665 - val_loss: 0.1148 - val_matthews_correlation: 0.6520
#
# Epoch 00020: val_matthews_correlation did not improve from 0.75789
# Epoch 21/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1044 - matthews_correlation: 0.6432 - val_loss: 0.1042 - val_matthews_correlation: 0.6733
#
# Epoch 00021: val_matthews_correlation did not improve from 0.75789
# Epoch 22/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0964 - matthews_correlation: 0.6761 - val_loss: 0.0918 - val_matthews_correlation: 0.7417
#
# Epoch 00022: val_matthews_correlation did not improve from 0.75789
# Epoch 23/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0981 - matthews_correlation: 0.6771 - val_loss: 0.0995 - val_matthews_correlation: 0.7498
#
# Epoch 00023: val_matthews_correlation did not improve from 0.75789
# Epoch 24/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0954 - matthews_correlation: 0.6667 - val_loss: 0.0913 - val_matthews_correlation: 0.7057
#
# Epoch 00024: val_matthews_correlation did not improve from 0.75789
# Epoch 25/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1122 - matthews_correlation: 0.5872 - val_loss: 0.0921 - val_matthews_correlation: 0.7452
#
# Epoch 00025: val_matthews_correlation did not improve from 0.75789
# Epoch 26/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1009 - matthews_correlation: 0.7122 - val_loss: 0.1044 - val_matthews_correlation: 0.6476
#
# Epoch 00026: val_matthews_correlation did not improve from 0.75789
# Epoch 27/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0949 - matthews_correlation: 0.6935 - val_loss: 0.0890 - val_matthews_correlation: 0.7180
#
# Epoch 00027: val_matthews_correlation did not improve from 0.75789
# Epoch 28/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0951 - matthews_correlation: 0.6749 - val_loss: 0.0906 - val_matthews_correlation: 0.7005
#
# Epoch 00028: val_matthews_correlation did not improve from 0.75789
# Epoch 29/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0943 - matthews_correlation: 0.7056 - val_loss: 0.0973 - val_matthews_correlation: 0.6595
#
# Epoch 00029: val_matthews_correlation did not improve from 0.75789
# Epoch 30/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0929 - matthews_correlation: 0.6888 - val_loss: 0.0992 - val_matthews_correlation: 0.6909
#
# Epoch 00030: val_matthews_correlation did not improve from 0.75789
# Epoch 31/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1062 - matthews_correlation: 0.6626 - val_loss: 0.0969 - val_matthews_correlation: 0.6986
#
# Epoch 00031: val_matthews_correlation did not improve from 0.75789
# Epoch 32/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0945 - matthews_correlation: 0.6846 - val_loss: 0.0925 - val_matthews_correlation: 0.7154
#
# Epoch 00032: val_matthews_correlation did not improve from 0.75789
# Epoch 33/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0917 - matthews_correlation: 0.7068 - val_loss: 0.0978 - val_matthews_correlation: 0.6681
#
# Epoch 00033: val_matthews_correlation did not improve from 0.75789
# Epoch 34/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0891 - matthews_correlation: 0.6961 - val_loss: 0.0904 - val_matthews_correlation: 0.7022
#
# Epoch 00034: val_matthews_correlation did not improve from 0.75789
# Epoch 35/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0905 - matthews_correlation: 0.6853 - val_loss: 0.0898 - val_matthews_correlation: 0.6839
#
# Epoch 00035: val_matthews_correlation did not improve from 0.75789
# Epoch 36/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0882 - matthews_correlation: 0.7280 - val_loss: 0.0939 - val_matthews_correlation: 0.7380
#
# Epoch 00036: val_matthews_correlation did not improve from 0.75789
# Epoch 37/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0885 - matthews_correlation: 0.6864 - val_loss: 0.1061 - val_matthews_correlation: 0.6638
#
# Epoch 00037: val_matthews_correlation did not improve from 0.75789
# Epoch 38/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0887 - matthews_correlation: 0.7074 - val_loss: 0.0912 - val_matthews_correlation: 0.7451
#
# Epoch 00038: val_matthews_correlation did not improve from 0.75789
# Epoch 39/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0940 - matthews_correlation: 0.7135 - val_loss: 0.0906 - val_matthews_correlation: 0.6828
#
# Epoch 00039: val_matthews_correlation did not improve from 0.75789
# Epoch 40/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0939 - matthews_correlation: 0.6355 - val_loss: 0.0929 - val_matthews_correlation: 0.6804
#
# Epoch 00040: val_matthews_correlation did not improve from 0.75789
# Epoch 41/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0911 - matthews_correlation: 0.6865 - val_loss: 0.0917 - val_matthews_correlation: 0.6621
#
# Epoch 00041: val_matthews_correlation did not improve from 0.75789
# Epoch 42/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0865 - matthews_correlation: 0.6927 - val_loss: 0.0904 - val_matthews_correlation: 0.6521
#
# Epoch 00042: val_matthews_correlation did not improve from 0.75789
# Epoch 43/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0886 - matthews_correlation: 0.7342 - val_loss: 0.1019 - val_matthews_correlation: 0.7013
#
# Epoch 00043: val_matthews_correlation did not improve from 0.75789
# Epoch 44/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0830 - matthews_correlation: 0.7216 - val_loss: 0.0927 - val_matthews_correlation: 0.6509
#
# Epoch 00044: val_matthews_correlation did not improve from 0.75789
# Epoch 45/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0874 - matthews_correlation: 0.6713 - val_loss: 0.1107 - val_matthews_correlation: 0.6559
#
# Epoch 00045: val_matthews_correlation did not improve from 0.75789
# Epoch 46/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0895 - matthews_correlation: 0.7241 - val_loss: 0.0925 - val_matthews_correlation: 0.6856
#
# Epoch 00046: val_matthews_correlation did not improve from 0.75789
# Epoch 47/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0863 - matthews_correlation: 0.7049 - val_loss: 0.1047 - val_matthews_correlation: 0.6522
#
# Epoch 00047: val_matthews_correlation did not improve from 0.75789
# Epoch 48/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0828 - matthews_correlation: 0.7505 - val_loss: 0.1045 - val_matthews_correlation: 0.6113
#
# Epoch 00048: val_matthews_correlation did not improve from 0.75789
# Epoch 49/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0840 - matthews_correlation: 0.6842 - val_loss: 0.0867 - val_matthews_correlation: 0.7393
#
# Epoch 00049: val_matthews_correlation did not improve from 0.75789
# Epoch 50/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1003 - matthews_correlation: 0.6384 - val_loss: 0.0980 - val_matthews_correlation: 0.7268
#
# Epoch 00050: val_matthews_correlation did not improve from 0.75789
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 4s 2ms/step - loss: 0.3681 - matthews_correlation: 0.0069 - val_loss: 0.2564 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2394 - matthews_correlation: 0.0000e+00 - val_loss: 0.2369 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2125 - matthews_correlation: 0.0524 - val_loss: 0.1945 - val_matthews_correlation: 0.3051
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.30512, saving model to weights_2.h5
# Epoch 4/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2108 - matthews_correlation: 0.1427 - val_loss: 0.2032 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.30512
# Epoch 5/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1952 - matthews_correlation: 0.1118 - val_loss: 0.1733 - val_matthews_correlation: 0.3496
#
# Epoch 00005: val_matthews_correlation improved from 0.30512 to 0.34964, saving model to weights_2.h5
# Epoch 6/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1606 - matthews_correlation: 0.2364 - val_loss: 0.1545 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.34964
# Epoch 7/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1754 - matthews_correlation: 0.3400 - val_loss: 0.2048 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00007: val_matthews_correlation did not improve from 0.34964
# Epoch 8/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2025 - matthews_correlation: 0.0841 - val_loss: 0.1836 - val_matthews_correlation: 0.1873
#
# Epoch 00008: val_matthews_correlation did not improve from 0.34964
# Epoch 9/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1773 - matthews_correlation: 0.1794 - val_loss: 0.1660 - val_matthews_correlation: 0.3793
#
# Epoch 00009: val_matthews_correlation improved from 0.34964 to 0.37932, saving model to weights_2.h5
# Epoch 10/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1394 - matthews_correlation: 0.4004 - val_loss: 0.1210 - val_matthews_correlation: 0.4414
#
# Epoch 00010: val_matthews_correlation improved from 0.37932 to 0.44140, saving model to weights_2.h5
# Epoch 11/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1101 - matthews_correlation: 0.6402 - val_loss: 0.1254 - val_matthews_correlation: 0.4367
#
# Epoch 00011: val_matthews_correlation did not improve from 0.44140
# Epoch 12/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0989 - matthews_correlation: 0.6942 - val_loss: 0.1214 - val_matthews_correlation: 0.5810
#
# Epoch 00012: val_matthews_correlation improved from 0.44140 to 0.58103, saving model to weights_2.h5
# Epoch 13/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1084 - matthews_correlation: 0.6540 - val_loss: 0.1198 - val_matthews_correlation: 0.6319
#
# Epoch 00013: val_matthews_correlation improved from 0.58103 to 0.63193, saving model to weights_2.h5
# Epoch 14/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1075 - matthews_correlation: 0.6189 - val_loss: 0.1139 - val_matthews_correlation: 0.5732
#
# Epoch 00014: val_matthews_correlation did not improve from 0.63193
# Epoch 15/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1046 - matthews_correlation: 0.6000 - val_loss: 0.1143 - val_matthews_correlation: 0.5884
#
# Epoch 00015: val_matthews_correlation did not improve from 0.63193
# Epoch 16/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1051 - matthews_correlation: 0.6143 - val_loss: 0.1181 - val_matthews_correlation: 0.6298
#
# Epoch 00016: val_matthews_correlation did not improve from 0.63193
# Epoch 17/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0996 - matthews_correlation: 0.6439 - val_loss: 0.1139 - val_matthews_correlation: 0.5402
#
# Epoch 00017: val_matthews_correlation did not improve from 0.63193
# Epoch 18/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0956 - matthews_correlation: 0.6863 - val_loss: 0.1146 - val_matthews_correlation: 0.6263
#
# Epoch 00018: val_matthews_correlation did not improve from 0.63193
# Epoch 19/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0934 - matthews_correlation: 0.6393 - val_loss: 0.1186 - val_matthews_correlation: 0.6071
#
# Epoch 00019: val_matthews_correlation did not improve from 0.63193
# Epoch 20/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0937 - matthews_correlation: 0.6855 - val_loss: 0.1209 - val_matthews_correlation: 0.3868
#
# Epoch 00020: val_matthews_correlation did not improve from 0.63193
# Epoch 21/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0937 - matthews_correlation: 0.7055 - val_loss: 0.1149 - val_matthews_correlation: 0.4523
#
# Epoch 00021: val_matthews_correlation did not improve from 0.63193
# Epoch 22/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0990 - matthews_correlation: 0.6533 - val_loss: 0.1132 - val_matthews_correlation: 0.5372
#
# Epoch 00022: val_matthews_correlation did not improve from 0.63193
# Epoch 23/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0932 - matthews_correlation: 0.6759 - val_loss: 0.1192 - val_matthews_correlation: 0.6399
#
# Epoch 00023: val_matthews_correlation improved from 0.63193 to 0.63989, saving model to weights_2.h5
# Epoch 24/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0911 - matthews_correlation: 0.6873 - val_loss: 0.1112 - val_matthews_correlation: 0.5464
#
# Epoch 00024: val_matthews_correlation did not improve from 0.63989
# Epoch 25/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0868 - matthews_correlation: 0.7175 - val_loss: 0.1135 - val_matthews_correlation: 0.5470
#
# Epoch 00025: val_matthews_correlation did not improve from 0.63989
# Epoch 26/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0961 - matthews_correlation: 0.5879 - val_loss: 0.1151 - val_matthews_correlation: 0.3326
#
# Epoch 00026: val_matthews_correlation did not improve from 0.63989
# Epoch 27/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0874 - matthews_correlation: 0.6654 - val_loss: 0.1232 - val_matthews_correlation: 0.5770
#
# Epoch 00027: val_matthews_correlation did not improve from 0.63989
# Epoch 28/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0889 - matthews_correlation: 0.7000 - val_loss: 0.1217 - val_matthews_correlation: 0.5464
#
# Epoch 00028: val_matthews_correlation did not improve from 0.63989
# Epoch 29/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0909 - matthews_correlation: 0.6811 - val_loss: 0.1124 - val_matthews_correlation: 0.5535
#
# Epoch 00029: val_matthews_correlation did not improve from 0.63989
# Epoch 30/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0922 - matthews_correlation: 0.6315 - val_loss: 0.1250 - val_matthews_correlation: 0.5692
#
# Epoch 00030: val_matthews_correlation did not improve from 0.63989
# Epoch 31/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0900 - matthews_correlation: 0.6780 - val_loss: 0.1154 - val_matthews_correlation: 0.5636
#
# Epoch 00031: val_matthews_correlation did not improve from 0.63989
# Epoch 32/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0927 - matthews_correlation: 0.6633 - val_loss: 0.1211 - val_matthews_correlation: 0.5890
#
# Epoch 00032: val_matthews_correlation did not improve from 0.63989
# Epoch 33/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0893 - matthews_correlation: 0.6748 - val_loss: 0.1177 - val_matthews_correlation: 0.5159
#
# Epoch 00033: val_matthews_correlation did not improve from 0.63989
# Epoch 34/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0845 - matthews_correlation: 0.7042 - val_loss: 0.1216 - val_matthews_correlation: 0.5723
#
# Epoch 00034: val_matthews_correlation did not improve from 0.63989
# Epoch 35/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0829 - matthews_correlation: 0.7126 - val_loss: 0.1196 - val_matthews_correlation: 0.5917
#
# Epoch 00035: val_matthews_correlation did not improve from 0.63989
# Epoch 36/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0897 - matthews_correlation: 0.6811 - val_loss: 0.1285 - val_matthews_correlation: 0.6234
#
# Epoch 00036: val_matthews_correlation did not improve from 0.63989
# Epoch 37/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0903 - matthews_correlation: 0.6399 - val_loss: 0.1278 - val_matthews_correlation: 0.4910
#
# Epoch 00037: val_matthews_correlation did not improve from 0.63989
# Epoch 38/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0888 - matthews_correlation: 0.6979 - val_loss: 0.1188 - val_matthews_correlation: 0.5215
#
# Epoch 00038: val_matthews_correlation did not improve from 0.63989
# Epoch 39/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0845 - matthews_correlation: 0.6697 - val_loss: 0.1105 - val_matthews_correlation: 0.6387
#
# Epoch 00039: val_matthews_correlation did not improve from 0.63989
# Epoch 40/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0839 - matthews_correlation: 0.7384 - val_loss: 0.1141 - val_matthews_correlation: 0.6094
#
# Epoch 00040: val_matthews_correlation did not improve from 0.63989
# Epoch 41/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0835 - matthews_correlation: 0.7041 - val_loss: 0.1212 - val_matthews_correlation: 0.5513
#
# Epoch 00041: val_matthews_correlation did not improve from 0.63989
# Epoch 42/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0802 - matthews_correlation: 0.7124 - val_loss: 0.1179 - val_matthews_correlation: 0.4549
#
# Epoch 00042: val_matthews_correlation did not improve from 0.63989
# Epoch 43/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0870 - matthews_correlation: 0.7298 - val_loss: 0.1230 - val_matthews_correlation: 0.6258
#
# Epoch 00043: val_matthews_correlation did not improve from 0.63989
# Epoch 44/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0860 - matthews_correlation: 0.6866 - val_loss: 0.1145 - val_matthews_correlation: 0.6260
#
# Epoch 00044: val_matthews_correlation did not improve from 0.63989
# Epoch 45/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0767 - matthews_correlation: 0.7470 - val_loss: 0.1186 - val_matthews_correlation: 0.5923
#
# Epoch 00045: val_matthews_correlation did not improve from 0.63989
# Epoch 46/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0756 - matthews_correlation: 0.7485 - val_loss: 0.1162 - val_matthews_correlation: 0.5982
#
# Epoch 00046: val_matthews_correlation did not improve from 0.63989
# Epoch 47/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0726 - matthews_correlation: 0.7573 - val_loss: 0.1413 - val_matthews_correlation: 0.6221
#
# Epoch 00047: val_matthews_correlation did not improve from 0.63989
# Epoch 48/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0834 - matthews_correlation: 0.7352 - val_loss: 0.1351 - val_matthews_correlation: 0.5102
#
# Epoch 00048: val_matthews_correlation did not improve from 0.63989
# Epoch 49/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0848 - matthews_correlation: 0.6666 - val_loss: 0.1212 - val_matthews_correlation: 0.5890
#
# Epoch 00049: val_matthews_correlation did not improve from 0.63989
# Epoch 50/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0885 - matthews_correlation: 0.7011 - val_loss: 0.1177 - val_matthews_correlation: 0.6102
#
# Epoch 00050: val_matthews_correlation did not improve from 0.63989
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 4s 2ms/step - loss: 0.3809 - matthews_correlation: 0.0026 - val_loss: 0.2451 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2367 - matthews_correlation: 0.0000e+00 - val_loss: 0.2525 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2282 - matthews_correlation: 0.0000e+00 - val_loss: 0.2274 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2095 - matthews_correlation: 0.0514 - val_loss: 0.1890 - val_matthews_correlation: 0.2530
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.25301, saving model to weights_3.h5
# Epoch 5/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1934 - matthews_correlation: 0.2766 - val_loss: 0.1721 - val_matthews_correlation: 0.2530
#
# Epoch 00005: val_matthews_correlation did not improve from 0.25301
# Epoch 6/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1820 - matthews_correlation: 0.2038 - val_loss: 0.1661 - val_matthews_correlation: 0.2741
#
# Epoch 00006: val_matthews_correlation improved from 0.25301 to 0.27415, saving model to weights_3.h5
# Epoch 7/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1602 - matthews_correlation: 0.3346 - val_loss: 0.1476 - val_matthews_correlation: 0.4415
#
# Epoch 00007: val_matthews_correlation improved from 0.27415 to 0.44151, saving model to weights_3.h5
# Epoch 8/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1490 - matthews_correlation: 0.3549 - val_loss: 0.1397 - val_matthews_correlation: 0.5274
#
# Epoch 00008: val_matthews_correlation improved from 0.44151 to 0.52741, saving model to weights_3.h5
# Epoch 9/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1199 - matthews_correlation: 0.5847 - val_loss: 0.1137 - val_matthews_correlation: 0.5785
#
# Epoch 00009: val_matthews_correlation improved from 0.52741 to 0.57853, saving model to weights_3.h5
# Epoch 10/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1087 - matthews_correlation: 0.6439 - val_loss: 0.1155 - val_matthews_correlation: 0.4802
#
# Epoch 00010: val_matthews_correlation did not improve from 0.57853
# Epoch 11/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1088 - matthews_correlation: 0.6403 - val_loss: 0.1151 - val_matthews_correlation: 0.5728
#
# Epoch 00011: val_matthews_correlation did not improve from 0.57853
# Epoch 12/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1026 - matthews_correlation: 0.6503 - val_loss: 0.1141 - val_matthews_correlation: 0.6356
#
# Epoch 00012: val_matthews_correlation improved from 0.57853 to 0.63563, saving model to weights_3.h5
# Epoch 13/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0988 - matthews_correlation: 0.6492 - val_loss: 0.1106 - val_matthews_correlation: 0.5539
#
# Epoch 00013: val_matthews_correlation did not improve from 0.63563
# Epoch 14/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0998 - matthews_correlation: 0.6664 - val_loss: 0.1150 - val_matthews_correlation: 0.5495
#
# Epoch 00014: val_matthews_correlation did not improve from 0.63563
# Epoch 15/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1072 - matthews_correlation: 0.6442 - val_loss: 0.1164 - val_matthews_correlation: 0.5140
#
# Epoch 00015: val_matthews_correlation did not improve from 0.63563
# Epoch 16/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1033 - matthews_correlation: 0.6108 - val_loss: 0.1173 - val_matthews_correlation: 0.6217
#
# Epoch 00016: val_matthews_correlation did not improve from 0.63563
# Epoch 17/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0989 - matthews_correlation: 0.6410 - val_loss: 0.1074 - val_matthews_correlation: 0.6491
#
# Epoch 00017: val_matthews_correlation improved from 0.63563 to 0.64911, saving model to weights_3.h5
# Epoch 18/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1040 - matthews_correlation: 0.6297 - val_loss: 0.1096 - val_matthews_correlation: 0.4977
#
# Epoch 00018: val_matthews_correlation did not improve from 0.64911
# Epoch 19/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1143 - matthews_correlation: 0.6597 - val_loss: 0.1070 - val_matthews_correlation: 0.4699
#
# Epoch 00019: val_matthews_correlation did not improve from 0.64911
# Epoch 20/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1014 - matthews_correlation: 0.6287 - val_loss: 0.1160 - val_matthews_correlation: 0.5026
#
# Epoch 00020: val_matthews_correlation did not improve from 0.64911
# Epoch 21/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0971 - matthews_correlation: 0.6525 - val_loss: 0.1061 - val_matthews_correlation: 0.6660
#
# Epoch 00021: val_matthews_correlation improved from 0.64911 to 0.66604, saving model to weights_3.h5
# Epoch 22/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0989 - matthews_correlation: 0.6660 - val_loss: 0.1050 - val_matthews_correlation: 0.5788
#
# Epoch 00022: val_matthews_correlation did not improve from 0.66604
# Epoch 23/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0961 - matthews_correlation: 0.6183 - val_loss: 0.1086 - val_matthews_correlation: 0.4974
#
# Epoch 00023: val_matthews_correlation did not improve from 0.66604
# Epoch 24/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0945 - matthews_correlation: 0.6695 - val_loss: 0.1060 - val_matthews_correlation: 0.5008
#
# Epoch 00024: val_matthews_correlation did not improve from 0.66604
# Epoch 25/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0984 - matthews_correlation: 0.6279 - val_loss: 0.1080 - val_matthews_correlation: 0.5597
#
# Epoch 00025: val_matthews_correlation did not improve from 0.66604
# Epoch 26/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0968 - matthews_correlation: 0.6600 - val_loss: 0.1087 - val_matthews_correlation: 0.4789
#
# Epoch 00026: val_matthews_correlation did not improve from 0.66604
# Epoch 27/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0929 - matthews_correlation: 0.7094 - val_loss: 0.1028 - val_matthews_correlation: 0.5817
#
# Epoch 00027: val_matthews_correlation did not improve from 0.66604
# Epoch 28/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0914 - matthews_correlation: 0.6518 - val_loss: 0.1000 - val_matthews_correlation: 0.6736
#
# Epoch 00028: val_matthews_correlation improved from 0.66604 to 0.67355, saving model to weights_3.h5
# Epoch 29/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0922 - matthews_correlation: 0.6715 - val_loss: 0.1026 - val_matthews_correlation: 0.6062
#
# Epoch 00029: val_matthews_correlation did not improve from 0.67355
# Epoch 30/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0970 - matthews_correlation: 0.6724 - val_loss: 0.1012 - val_matthews_correlation: 0.6124
#
# Epoch 00030: val_matthews_correlation did not improve from 0.67355
# Epoch 31/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0964 - matthews_correlation: 0.7230 - val_loss: 0.1082 - val_matthews_correlation: 0.5288
#
# Epoch 00031: val_matthews_correlation did not improve from 0.67355
# Epoch 32/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1038 - matthews_correlation: 0.5898 - val_loss: 0.1116 - val_matthews_correlation: 0.5116
#
# Epoch 00032: val_matthews_correlation did not improve from 0.67355
# Epoch 33/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0938 - matthews_correlation: 0.7070 - val_loss: 0.0988 - val_matthews_correlation: 0.5126
#
# Epoch 00033: val_matthews_correlation did not improve from 0.67355
# Epoch 34/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0893 - matthews_correlation: 0.6518 - val_loss: 0.1000 - val_matthews_correlation: 0.5702
#
# Epoch 00034: val_matthews_correlation did not improve from 0.67355
# Epoch 35/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0900 - matthews_correlation: 0.6955 - val_loss: 0.0999 - val_matthews_correlation: 0.6192
#
# Epoch 00035: val_matthews_correlation did not improve from 0.67355
# Epoch 36/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0870 - matthews_correlation: 0.6786 - val_loss: 0.0926 - val_matthews_correlation: 0.6655
#
# Epoch 00036: val_matthews_correlation did not improve from 0.67355
# Epoch 37/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0866 - matthews_correlation: 0.6877 - val_loss: 0.1037 - val_matthews_correlation: 0.7176
#
# Epoch 00037: val_matthews_correlation improved from 0.67355 to 0.71763, saving model to weights_3.h5
# Epoch 38/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0915 - matthews_correlation: 0.7195 - val_loss: 0.0957 - val_matthews_correlation: 0.6001
#
# Epoch 00038: val_matthews_correlation did not improve from 0.71763
# Epoch 39/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0896 - matthews_correlation: 0.6914 - val_loss: 0.0945 - val_matthews_correlation: 0.5702
#
# Epoch 00039: val_matthews_correlation did not improve from 0.71763
# Epoch 40/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0868 - matthews_correlation: 0.7048 - val_loss: 0.1013 - val_matthews_correlation: 0.5113
#
# Epoch 00040: val_matthews_correlation did not improve from 0.71763
# Epoch 41/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0867 - matthews_correlation: 0.7113 - val_loss: 0.1001 - val_matthews_correlation: 0.4929
#
# Epoch 00041: val_matthews_correlation did not improve from 0.71763
# Epoch 42/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0822 - matthews_correlation: 0.7020 - val_loss: 0.1030 - val_matthews_correlation: 0.5126
#
# Epoch 00042: val_matthews_correlation did not improve from 0.71763
# Epoch 43/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0839 - matthews_correlation: 0.7246 - val_loss: 0.0967 - val_matthews_correlation: 0.5154
#
# Epoch 00043: val_matthews_correlation did not improve from 0.71763
# Epoch 44/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0918 - matthews_correlation: 0.6711 - val_loss: 0.1097 - val_matthews_correlation: 0.4542
#
# Epoch 00044: val_matthews_correlation did not improve from 0.71763
# Epoch 45/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0890 - matthews_correlation: 0.6634 - val_loss: 0.0994 - val_matthews_correlation: 0.5164
#
# Epoch 00045: val_matthews_correlation did not improve from 0.71763
# Epoch 46/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0839 - matthews_correlation: 0.7272 - val_loss: 0.0947 - val_matthews_correlation: 0.6010
#
# Epoch 00046: val_matthews_correlation did not improve from 0.71763
# Epoch 47/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0828 - matthews_correlation: 0.7112 - val_loss: 0.0965 - val_matthews_correlation: 0.6660
#
# Epoch 00047: val_matthews_correlation did not improve from 0.71763
# Epoch 48/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0865 - matthews_correlation: 0.7193 - val_loss: 0.1033 - val_matthews_correlation: 0.5288
#
# Epoch 00048: val_matthews_correlation did not improve from 0.71763
# Epoch 49/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0785 - matthews_correlation: 0.6937 - val_loss: 0.1034 - val_matthews_correlation: 0.6124
#
# Epoch 00049: val_matthews_correlation did not improve from 0.71763
# Epoch 50/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0769 - matthews_correlation: 0.7297 - val_loss: 0.1113 - val_matthews_correlation: 0.5681
#
# Epoch 00050: val_matthews_correlation did not improve from 0.71763
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 4s 2ms/step - loss: 0.3814 - matthews_correlation: 0.0086 - val_loss: 0.2577 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2444 - matthews_correlation: 0.0000e+00 - val_loss: 0.2217 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2273 - matthews_correlation: 0.0000e+00 - val_loss: 0.2173 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2166 - matthews_correlation: -9.8538e-04 - val_loss: 0.1906 - val_matthews_correlation: 0.3699
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.36987, saving model to weights_4.h5
# Epoch 5/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1956 - matthews_correlation: 0.0389 - val_loss: 0.1775 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.36987
# Epoch 6/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1805 - matthews_correlation: 0.0485 - val_loss: 0.1600 - val_matthews_correlation: 0.4175
#
# Epoch 00006: val_matthews_correlation improved from 0.36987 to 0.41752, saving model to weights_4.h5
# Epoch 7/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1478 - matthews_correlation: 0.3338 - val_loss: 0.1306 - val_matthews_correlation: 0.4633
#
# Epoch 00007: val_matthews_correlation improved from 0.41752 to 0.46329, saving model to weights_4.h5
# Epoch 8/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1263 - matthews_correlation: 0.5009 - val_loss: 0.1148 - val_matthews_correlation: 0.6259
#
# Epoch 00008: val_matthews_correlation improved from 0.46329 to 0.62587, saving model to weights_4.h5
# Epoch 9/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1069 - matthews_correlation: 0.6238 - val_loss: 0.1146 - val_matthews_correlation: 0.6357
#
# Epoch 00009: val_matthews_correlation improved from 0.62587 to 0.63566, saving model to weights_4.h5
# Epoch 10/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1018 - matthews_correlation: 0.6547 - val_loss: 0.1312 - val_matthews_correlation: 0.6329
#
# Epoch 00010: val_matthews_correlation did not improve from 0.63566
# Epoch 11/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1109 - matthews_correlation: 0.5865 - val_loss: 0.1203 - val_matthews_correlation: 0.4261
#
# Epoch 00011: val_matthews_correlation did not improve from 0.63566
# Epoch 12/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1061 - matthews_correlation: 0.5979 - val_loss: 0.1137 - val_matthews_correlation: 0.4254
#
# Epoch 00012: val_matthews_correlation did not improve from 0.63566
# Epoch 13/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1024 - matthews_correlation: 0.6543 - val_loss: 0.1140 - val_matthews_correlation: 0.4287
#
# Epoch 00013: val_matthews_correlation did not improve from 0.63566
# Epoch 14/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1026 - matthews_correlation: 0.6161 - val_loss: 0.1128 - val_matthews_correlation: 0.6049
#
# Epoch 00014: val_matthews_correlation did not improve from 0.63566
# Epoch 15/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0962 - matthews_correlation: 0.6762 - val_loss: 0.1297 - val_matthews_correlation: 0.3862
#
# Epoch 00015: val_matthews_correlation did not improve from 0.63566
# Epoch 16/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1057 - matthews_correlation: 0.5076 - val_loss: 0.1282 - val_matthews_correlation: 0.4930
#
# Epoch 00016: val_matthews_correlation did not improve from 0.63566
# Epoch 17/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1026 - matthews_correlation: 0.6701 - val_loss: 0.1124 - val_matthews_correlation: 0.6069
#
# Epoch 00017: val_matthews_correlation did not improve from 0.63566
# Epoch 18/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1068 - matthews_correlation: 0.6998 - val_loss: 0.1134 - val_matthews_correlation: 0.5883
#
# Epoch 00018: val_matthews_correlation did not improve from 0.63566
# Epoch 19/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0967 - matthews_correlation: 0.6854 - val_loss: 0.1108 - val_matthews_correlation: 0.4197
#
# Epoch 00019: val_matthews_correlation did not improve from 0.63566
# Epoch 20/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0972 - matthews_correlation: 0.6662 - val_loss: 0.1220 - val_matthews_correlation: 0.4413
#
# Epoch 00020: val_matthews_correlation did not improve from 0.63566
# Epoch 21/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0900 - matthews_correlation: 0.6757 - val_loss: 0.1081 - val_matthews_correlation: 0.6277
#
# Epoch 00021: val_matthews_correlation did not improve from 0.63566
# Epoch 22/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0908 - matthews_correlation: 0.6643 - val_loss: 0.1114 - val_matthews_correlation: 0.4413
#
# Epoch 00022: val_matthews_correlation did not improve from 0.63566
# Epoch 23/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0950 - matthews_correlation: 0.6611 - val_loss: 0.1089 - val_matthews_correlation: 0.5524
#
# Epoch 00023: val_matthews_correlation did not improve from 0.63566
# Epoch 24/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0911 - matthews_correlation: 0.7190 - val_loss: 0.1105 - val_matthews_correlation: 0.5703
#
# Epoch 00024: val_matthews_correlation did not improve from 0.63566
# Epoch 25/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0916 - matthews_correlation: 0.6730 - val_loss: 0.1111 - val_matthews_correlation: 0.6131
#
# Epoch 00025: val_matthews_correlation did not improve from 0.63566
# Epoch 26/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0882 - matthews_correlation: 0.7134 - val_loss: 0.1095 - val_matthews_correlation: 0.5391
#
# Epoch 00026: val_matthews_correlation did not improve from 0.63566
# Epoch 27/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0908 - matthews_correlation: 0.7224 - val_loss: 0.1246 - val_matthews_correlation: 0.4580
#
# Epoch 00027: val_matthews_correlation did not improve from 0.63566
# Epoch 28/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1013 - matthews_correlation: 0.6356 - val_loss: 0.1079 - val_matthews_correlation: 0.6586
#
# Epoch 00028: val_matthews_correlation improved from 0.63566 to 0.65861, saving model to weights_4.h5
# Epoch 29/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0912 - matthews_correlation: 0.6665 - val_loss: 0.1209 - val_matthews_correlation: 0.6041
#
# Epoch 00029: val_matthews_correlation did not improve from 0.65861
# Epoch 30/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0927 - matthews_correlation: 0.7102 - val_loss: 0.1079 - val_matthews_correlation: 0.5756
#
# Epoch 00030: val_matthews_correlation did not improve from 0.65861
# Epoch 31/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0870 - matthews_correlation: 0.7281 - val_loss: 0.1245 - val_matthews_correlation: 0.4575
#
# Epoch 00031: val_matthews_correlation did not improve from 0.65861
# Epoch 32/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0901 - matthews_correlation: 0.6765 - val_loss: 0.1036 - val_matthews_correlation: 0.6335
#
# Epoch 00032: val_matthews_correlation did not improve from 0.65861
# Epoch 33/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0886 - matthews_correlation: 0.7182 - val_loss: 0.1163 - val_matthews_correlation: 0.5510
#
# Epoch 00033: val_matthews_correlation did not improve from 0.65861
# Epoch 34/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0876 - matthews_correlation: 0.7412 - val_loss: 0.1167 - val_matthews_correlation: 0.6564
#
# Epoch 00034: val_matthews_correlation did not improve from 0.65861
# Epoch 35/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0845 - matthews_correlation: 0.6901 - val_loss: 0.1127 - val_matthews_correlation: 0.5826
#
# Epoch 00035: val_matthews_correlation did not improve from 0.65861
# Epoch 36/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0847 - matthews_correlation: 0.6838 - val_loss: 0.1111 - val_matthews_correlation: 0.4583
#
# Epoch 00036: val_matthews_correlation did not improve from 0.65861
# Epoch 37/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0828 - matthews_correlation: 0.7347 - val_loss: 0.1007 - val_matthews_correlation: 0.5791
#
# Epoch 00037: val_matthews_correlation did not improve from 0.65861
# Epoch 38/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0909 - matthews_correlation: 0.7192 - val_loss: 0.1085 - val_matthews_correlation: 0.6236
#
# Epoch 00038: val_matthews_correlation did not improve from 0.65861
# Epoch 39/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0835 - matthews_correlation: 0.7295 - val_loss: 0.1063 - val_matthews_correlation: 0.5255
#
# Epoch 00039: val_matthews_correlation did not improve from 0.65861
# Epoch 40/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0821 - matthews_correlation: 0.7227 - val_loss: 0.1111 - val_matthews_correlation: 0.6067
#
# Epoch 00040: val_matthews_correlation did not improve from 0.65861
# Epoch 41/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0824 - matthews_correlation: 0.7363 - val_loss: 0.1131 - val_matthews_correlation: 0.6588
#
# Epoch 00041: val_matthews_correlation improved from 0.65861 to 0.65884, saving model to weights_4.h5
# Epoch 42/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0866 - matthews_correlation: 0.7335 - val_loss: 0.1206 - val_matthews_correlation: 0.5367
#
# Epoch 00042: val_matthews_correlation did not improve from 0.65884
# Epoch 43/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0910 - matthews_correlation: 0.7076 - val_loss: 0.1162 - val_matthews_correlation: 0.6093
#
# Epoch 00043: val_matthews_correlation did not improve from 0.65884
# Epoch 44/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0952 - matthews_correlation: 0.6462 - val_loss: 0.1092 - val_matthews_correlation: 0.6046
#
# Epoch 00044: val_matthews_correlation did not improve from 0.65884
# Epoch 45/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0887 - matthews_correlation: 0.7093 - val_loss: 0.1072 - val_matthews_correlation: 0.5471
#
# Epoch 00045: val_matthews_correlation did not improve from 0.65884
# Epoch 46/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0852 - matthews_correlation: 0.7042 - val_loss: 0.1064 - val_matthews_correlation: 0.6148
#
# Epoch 00046: val_matthews_correlation did not improve from 0.65884
# Epoch 47/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0837 - matthews_correlation: 0.7307 - val_loss: 0.1128 - val_matthews_correlation: 0.5547
#
# Epoch 00047: val_matthews_correlation did not improve from 0.65884
# Epoch 48/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0826 - matthews_correlation: 0.7354 - val_loss: 0.1283 - val_matthews_correlation: 0.5538
#
# Epoch 00048: val_matthews_correlation did not improve from 0.65884
# Epoch 49/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0802 - matthews_correlation: 0.7557 - val_loss: 0.1083 - val_matthews_correlation: 0.6411
#
# Epoch 00049: val_matthews_correlation did not improve from 0.65884
# Epoch 50/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0820 - matthews_correlation: 0.7140 - val_loss: 0.1081 - val_matthews_correlation: 0.5691
#
# Epoch 00050: val_matthews_correlation did not improve from 0.65884
# ((2904,), (2904,))

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [00:22<00:00,  2.66it/s]

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../input/metadata_test.csv')
# Out:
# CPU times: user 12 ms, sys: 0 ns, total: 12 ms
# Wall time: 12.7 ms

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
# %%time
# First we daclarete a series of parameters to initiate the loading of the main data
# it is too large, it is impossible to load in one time, so we are doing it in dividing in 10 parts
first_sig = meta_test.index[0]
n_parts = 10
max_line = len(meta_test)
part_size = int(max_line / n_parts)
last_part = max_line % n_parts
print(first_sig, n_parts, max_line, part_size, last_part, n_parts * part_size + last_part)
# Here we create a list of lists with start index and end index for each of the 10 parts and one for the last partial part
start_end = [[x, x+part_size] for x in range(first_sig, max_line + first_sig, part_size)]
start_end = start_end[:-1] + [[start_end[-1][0], start_end[-1][0] + last_part]]
print(start_end)
X_test = []
# now, very like we did above with the train data, we convert the test data part by part
# transforming the 3 phases 800000 measurement in matrix (160,57)
for start, end in start_end:
    subset_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    for i in tqdm(subset_test.columns):
        id_measurement, phase = meta_test.loc[int(i)]
        subset_test_col = subset_test[i]
        subset_trans = transform_ts(subset_test_col)
        X_test.append([i, id_measurement, phase, subset_trans])
# Out:
# 8712 10 20337 2033 7 20337
# [[8712, 10745], [10745, 12778], [12778, 14811], [14811, 16844], [16844, 18877], [18877, 20910], [20910, 22943], [22943, 24976], [24976, 27009], [27009, 29042], [29042, 29049]]
# 100%|██████████| 2033/2033 [03:13<00:00, 10.48it/s]
# 100%|██████████| 2033/2033 [03:14<00:00, 10.29it/s]
# 100%|██████████| 2033/2033 [03:15<00:00, 10.26it/s]
# 100%|██████████| 2033/2033 [03:17<00:00, 10.32it/s]
# 100%|██████████| 2033/2033 [03:18<00:00, 10.24it/s]
# 100%|██████████| 2033/2033 [03:17<00:00, 10.39it/s]
# 100%|██████████| 2033/2033 [03:16<00:00, 10.35it/s]
# 100%|██████████| 2033/2033 [03:16<00:00, 10.35it/s]
# 100%|██████████| 2033/2033 [03:16<00:00, 10.43it/s]
# 100%|██████████| 2033/2033 [03:15<00:00, 10.39it/s]
# 100%|██████████| 7/7 [00:00<00:00,  8.33it/s]
# CPU times: user 34min 28s, sys: 26.3 s, total: 34min 54s
# Wall time: 34min 48s

# %%
X_test_input = np.asarray([np.concatenate([X_test[i][3],X_test[i+1][3], X_test[i+2][3]], axis=1) for i in range(0,len(X_test), 3)])
np.save("X_test.npy",X_test_input)
X_test_input.shape
# Out:
# (6779, 160, 57)

# %%
signals = X_test_input.reshape((len(X_test_input), X_test_input.shape[1]*X_test_input.shape[2]))
features_test = []

for signal in signals:
    features_test.append(entropy_and_fractal_dim(signal))

# %%
features_test = np.array(features_test).reshape((len(features_test), 7))
features_test = scaler.transform(features_test)

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict([X_test_input, features_test], batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 2s 297us/step
# 6779/6779 [==============================] - 2s 274us/step
# 6779/6779 [==============================] - 2s 273us/step
# 6779/6779 [==============================] - 2s 273us/step
# 6779/6779 [==============================] - 2s 270us/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('submission.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
submission.head(200).values
# Out:
# array([[8712,    0],
#        [8713,    0],
#        [8714,    0],
#        [8715,    0],
#        [8716,    0],
#        [8717,    0],
#        [8718,    0],
#        [8719,    0],
#        [8720,    0],
#        [8721,    0],
#        [8722,    0],
#        [8723,    0],
#        [8724,    0],
#        [8725,    0],
#        [8726,    0],
#        [8727,    0],
#        [8728,    0],
#        [8729,    0],
#        [8730,    0],
#        [8731,    0],
#        [8732,    0],
#        [8733,    0],
#        [8734,    0],
#        [8735,    0],
#        [8736,    0],
#        [8737,    0],
#        [8738,    0],
#        [8739,    0],
#        [8740,    0],
#        [8741,    0],
#        [8742,    0],
#        [8743,    0],
#        [8744,    0],
#        [8745,    0],
#        [8746,    0],
#        [8747,    0],
#        [8748,    0],
#        [8749,    0],
#        [8750,    0],
#        [8751,    0],
#        [8752,    0],
#        [8753,    0],
#        [8754,    0],
#        [8755,    0],
#        [8756,    0],
#        [8757,    0],
#        [8758,    0],
#        [8759,    0],
#        [8760,    0],
#        [8761,    0],
#        [8762,    0],
#        [8763,    0],
#        [8764,    0],
#        [8765,    0],
#        [8766,    0],
#        [8767,    0],
#        [8768,    0],
#        [8769,    0],
#        [8770,    0],
#        [8771,    0],
#        [8772,    0],
#        [8773,    0],
#        [8774,    0],
#        [8775,    0],
#        [8776,    0],
#        [8777,    0],
#        [8778,    0],
#        [8779,    0],
#        [8780,    0],
#        [8781,    0],
#        [8782,    0],
#        [8783,    0],
#        [8784,    0],
#        [8785,    0],
#        [8786,    0],
#        [8787,    0],
#        [8788,    0],
#        [8789,    0],
#        [8790,    0],
#        [8791,    0],
#        [8792,    0],
#        [8793,    0],
#        [8794,    0],
#        [8795,    0],
#        [8796,    0],
#        [8797,    0],
#        [8798,    0],
#        [8799,    0],
#        [8800,    0],
#        [8801,    0],
#        [8802,    0],
#        [8803,    0],
#        [8804,    0],
#        [8805,    0],
#        [8806,    0],
#        [8807,    0],
#        [8808,    0],
#        [8809,    0],
#        [8810,    0],
#        [8811,    0],
#        [8812,    0],
#        [8813,    0],
#        [8814,    0],
#        [8815,    0],
#        [8816,    0],
#        [8817,    0],
#        [8818,    0],
#        [8819,    0],
#        [8820,    0],
#        [8821,    0],
#        [8822,    0],
#        [8823,    0],
#        [8824,    0],
#        [8825,    0],
#        [8826,    0],
#        [8827,    0],
#        [8828,    0],
#        [8829,    0],
#        [8830,    0],
#        [8831,    0],
#        [8832,    0],
#        [8833,    0],
#        [8834,    0],
#        [8835,    0],
#        [8836,    0],
#        [8837,    0],
#        [8838,    0],
#        [8839,    0],
#        [8840,    0],
#        [8841,    0],
#        [8842,    0],
#        [8843,    0],
#        [8844,    0],
#        [8845,    0],
#        [8846,    0],
#        [8847,    0],
#        [8848,    0],
#        [8849,    0],
#        [8850,    0],
#        [8851,    0],
#        [8852,    0],
#        [8853,    0],
#        [8854,    0],
#        [8855,    0],
#        [8856,    0],
#        [8857,    0],
#        [8858,    0],
#        [8859,    0],
#        [8860,    0],
#        [8861,    0],
#        [8862,    0],
#        [8863,    0],
#        [8864,    0],
#        [8865,    0],
#        [8866,    0],
#        [8867,    0],
#        [8868,    0],
#        [8869,    0],
#        [8870,    0],
#        [8871,    0],
#        [8872,    0],
#        [8873,    0],
#        [8874,    0],
#        [8875,    0],
#        [8876,    0],
#        [8877,    0],
#        [8878,    0],
#        [8879,    0],
#        [8880,    0],
#        [8881,    0],
#        [8882,    0],
#        [8883,    0],
#        [8884,    0],
#        [8885,    0],
#        [8886,    0],
#        [8887,    0],
#        [8888,    0],
#        [8889,    0],
#        [8890,    0],
#        [8891,    0],
#        [8892,    0],
#        [8893,    0],
#        [8894,    0],
#        [8895,    0],
#        [8896,    0],
#        [8897,    0],
#        [8898,    0],
#        [8899,    0],
#        [8900,    0],
#        [8901,    1],
#        [8902,    1],
#        [8903,    1],
#        [8904,    0],
#        [8905,    0],
#        [8906,    0],
#        [8907,    0],
#        [8908,    0],
#        [8909,    0],
#        [8910,    0],
#        [8911,    0]])
